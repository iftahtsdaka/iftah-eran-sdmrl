# %%
# Imports
# -----------------------
# general
# -----------------------
import os

# -----------------------
# Gymnasium
# -----------------------
import gymnasium as gym
from gymnasium import spaces
import numpy as np

# -----------------------
# Stable Baselines 3
# -----------------------

from stable_baselines3 import DQN
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.env_util import make_vec_env

# %%
# -----------------------
# Global Constants
# -----------------------
TOTAL_DAILY_DEMAND = 1000
PENALTY_PER_WATER_UNIT = 1000
AGENT_WATER_VOLUME_MAX = 300
HOURS_IN_A_WEEK = 168

# -----------------------
# Helper Functions
# -----------------------
def discretize(value, bucket_size):
    """Rounds the value to the nearest multiple of bucket_size."""
    return int(round(value / bucket_size)) * bucket_size

def default_price_function(amount_to_buy, base_price):
    return min(amount_to_buy * base_price + 0.005 * base_price * (amount_to_buy - 1) ** 2,
               PENALTY_PER_WATER_UNIT)

def get_hourly_demand_pattern():
    hourly_demand = np.array([2, 2, 2, 2, 3, 5, 10, 12, 10, 8, 6, 5, 5, 5, 5, 6, 7, 9, 10, 9, 6, 4, 3, 2])
    hourly_demand = (hourly_demand / hourly_demand.sum()) * TOTAL_DAILY_DEMAND
    # For a week: 6 full days and 1 day at half demand
    hourly_demand = np.append(np.tile(hourly_demand, 6), hourly_demand / 2)
    return hourly_demand

def sample_demand(hour, std=10):
    pattern = get_hourly_demand_pattern()
    mean_demand = pattern[hour]
    return max(0, np.random.normal(mean_demand, std))

def get_water_prices(hours):
    base_prices = np.ones(24)
    base_prices[8:16] = 2  # More expensive between 8:00 and 16:00
    base_prices = np.tile(base_prices, 7)[:hours]
    return base_prices

# -----------------------
# Simplified Environment
# -----------------------
class SimplifiedWaterSupplyEnv(gym.Env):
    def __init__(self,
                 max_cycles=10,
                 hours_per_cycle=HOURS_IN_A_WEEK,
                 time_bucket_count=168,
                 water_bucket_count=300,
                 price_function=default_price_function):
        """
        max_cycles: number of cycles (e.g., weeks)
        hours_per_cycle: number of hours in one cycle (e.g., 168)
        time_bucket_count: discrete time steps per cycle (aggregated from hours)
        water_bucket_count: number of discrete water/demand levels
        price_function: function for computing water cost
        """
        super(SimplifiedWaterSupplyEnv, self).__init__()
        self.max_cycles = max_cycles
        self.hours_per_cycle = hours_per_cycle
        self.time_bucket_count = time_bucket_count
        self.price_function = price_function

        # How many original hours per bucket?
        self.aggregation_interval = hours_per_cycle // time_bucket_count

        # Determine the bucket size for water/demand.
        self.water_bucket_count = water_bucket_count
        self.water_bucket_size = AGENT_WATER_VOLUME_MAX / water_bucket_count

        # Observation: [water_level, price_A, price_B, demand, current_time_bucket]
        self.observation_space = spaces.Box(low=0, high=np.inf, shape=(5,), dtype=np.float32)
        # Action: how much water to buy from each source (continuous; later wrapped to discrete)
        self.action_space = spaces.Box(low=0, high=AGENT_WATER_VOLUME_MAX, shape=(2,), dtype=np.float32)

        # Pre-compute hourly prices and then aggregate them into time buckets.
        self.base_hourly_prices = get_water_prices(hours_per_cycle)
        self.source_A_base_prices = self._aggregate_prices(self.base_hourly_prices)
        self.source_B_base_prices = 1.5 * self.source_A_base_prices

        self.reset()

    def _aggregate_prices(self, hourly_prices):
        """Aggregate hourly prices into time buckets by averaging."""
        aggregated = []
        for i in range(self.time_bucket_count):
            start = i * self.aggregation_interval
            end = (i + 1) * self.aggregation_interval
            agg_price = np.mean(hourly_prices[start:end])
            aggregated.append(agg_price)
        return np.array(aggregated)

    def _aggregate_demand(self, start_hour):
        """Aggregate demand over the time bucket and discretize it."""
        demands = [sample_demand(h % self.hours_per_cycle) for h in range(start_hour, start_hour + self.aggregation_interval)]
        avg_demand = np.mean(demands)
        return discretize(avg_demand, self.water_bucket_size)

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        self.current_cycle = 0
        self.current_time_bucket = 0

        # Start with full water (discretized)
        self.water_level = discretize(AGENT_WATER_VOLUME_MAX, self.water_bucket_size)
        self.total_reward = 0.0

        # Initialize demand and prices for the first time bucket
        self.demand = self._aggregate_demand(0)
        self.price_A = self.source_A_base_prices[self.current_time_bucket]
        self.price_B = self.source_B_base_prices[self.current_time_bucket]
        return self._get_obs(), self._get_info()

    def step(self, action):
        buy_from_A, buy_from_B = action

        # Calculate penalty for unmet demand
        unmet_demand = max(0, self.demand - self.water_level)
        unmet_demand_penalty = unmet_demand * PENALTY_PER_WATER_UNIT

        # Subtract demand (and discretize afterward)
        self.water_level = max(0, self.water_level - self.demand)

        # Compute cost using the pricing function
        cost_A = self.price_function(buy_from_A, self.price_A)
        cost_B = self.price_function(buy_from_B, self.price_B)

        # Add purchased water and re-discretize
        self.water_level += (buy_from_A + buy_from_B)
        self.water_level = discretize(self.water_level, self.water_bucket_size)

        reward = - cost_A - cost_B - unmet_demand_penalty
        self.total_reward += reward

        # Advance the time bucket
        self.current_time_bucket += 1
        if self.current_time_bucket >= self.time_bucket_count:
            self.current_cycle += 1
            self.current_time_bucket = 0

        done = self.current_cycle >= self.max_cycles

        if not done:
            start_hour = self.current_time_bucket * self.aggregation_interval
            self.demand = self._aggregate_demand(start_hour)
            self.price_A = self.source_A_base_prices[self.current_time_bucket]
            self.price_B = self.source_B_base_prices[self.current_time_bucket]

        return self._get_obs(), reward, done, False, self._get_info()

    def _get_obs(self):
        return np.array([self.water_level, self.price_A, self.price_B, self.demand, self.current_time_bucket])

    def _get_info(self):
        return {
            "water_level": self.water_level,
            "price_A": self.price_A,
            "price_B": self.price_B,
            "demand": self.demand,
            "current_time_bucket": self.current_time_bucket,
            "current_cycle": self.current_cycle,
            "total_reward": self.total_reward
        }

    def render(self):
        info = self._get_info()
        print(info)

# -----------------------
# Discrete Wrappers
# -----------------------
class DiscreteActions(gym.ActionWrapper):
    """
    Wraps a continuous action space into a discrete one.
    The agent can buy water in increments of size_of_purchase.
    """
    def __init__(self, env, max_water_volume=AGENT_WATER_VOLUME_MAX, size_of_purchase=10):
        super().__init__(env)
        self.action_amount = max_water_volume // size_of_purchase + 1
        self.size_of_purchase = size_of_purchase
        # Flattened action space: two sources => action_amount^2 possible actions.
        self.action_space = spaces.Discrete(self.action_amount * self.action_amount)

    def action_to_quantity(self, action):
        from_source_1 = action // self.action_amount
        from_source_2 = action % self.action_amount
        return [from_source_1 * self.size_of_purchase, from_source_2 * self.size_of_purchase]

    def action(self, action):
        return self.action_to_quantity(action)

class DiscreteObservation(gym.ObservationWrapper):
    """
    Wraps the observation space into a single discrete index.
    Each component is discretized according to the provided resolutions.
    """
    def __init__(self, env, water_level_resolution=10, price_resolution=1, demand_resolution=10, time_resolution=1):
        super().__init__(env)
        self.water_level_resolution = water_level_resolution
        self.price_resolution = price_resolution
        self.demand_resolution = demand_resolution
        self.time_resolution = time_resolution

        self.amount_of_water = AGENT_WATER_VOLUME_MAX // water_level_resolution + 1
        self.amount_of_price = PENALTY_PER_WATER_UNIT // price_resolution + 1
        self.amount_of_demand = TOTAL_DAILY_DEMAND // demand_resolution + 1
        self.amount_of_time = self.env.time_bucket_count

        # The flattened observation index
        self.observation_space = spaces.Discrete(self.amount_of_water * 
                                                 self.amount_of_price * 
                                                 self.amount_of_price * 
                                                 self.amount_of_demand * 
                                                 self.amount_of_time)

    def observation(self, observation):
        # observation: [water_level, price_A, price_B, demand, current_time_bucket]
        water_level, price_A, price_B, demand, current_time_bucket = observation

        water_idx = int(water_level // self.water_level_resolution)
        price_A_idx = int(price_A // self.price_resolution)
        price_B_idx = int(price_B // self.price_resolution)
        demand_idx = int(demand // self.demand_resolution)
        time_idx = int(current_time_bucket // self.time_resolution)

        discrete_obs = (
            water_idx +
            self.amount_of_water * (
                price_A_idx +
                self.amount_of_price * (
                    price_B_idx +
                    self.amount_of_price * (
                        demand_idx +
                        self.amount_of_demand * time_idx
                    )
                )
            )
        )
        return discrete_obs

# %%
# -----------------------
# Environment Creation Function
# -----------------------
def create_env(time_buckets=5, water_buckets=5):
    """
    time_buckets: number of discrete time steps per cycle (also hours_per_cycle).
    water_buckets: number of discrete water levels (e.g., 5 levels).
    """
    env = SimplifiedWaterSupplyEnv(
        max_cycles=5,
        hours_per_cycle=time_buckets,          # each bucket represents one hour
        time_bucket_count=time_buckets,        # number of time steps equals time_buckets
        water_bucket_count=water_buckets - 1   # water_bucket_count divisions yield water_buckets levels
    )
    # Determine the purchase increment: AGENT_WATER_VOLUME_MAX divided by (water_buckets - 1)
    purchase_increment = AGENT_WATER_VOLUME_MAX // (water_buckets - 1)
    
    env = DiscreteActions(env, max_water_volume=AGENT_WATER_VOLUME_MAX, size_of_purchase=purchase_increment)
    env = DiscreteObservation(
        env,
        water_level_resolution=purchase_increment,  # This yields 5 water levels: 0,75,150,225,300
        price_resolution=250,                         # 1000//250 + 1 = 5 price buckets
        demand_resolution=250,                        # 1000//250 + 1 = 5 demand buckets
        time_resolution=1                             # each time bucket is one step
    )
    return env

# %%
# Create a vectorized environment (n_envs=1 for simplicity)
env = make_vec_env(lambda: create_env(time_buckets=5, water_buckets=5), n_envs=1)
# Create and configure the DQN model
model = DQN("MlpPolicy", env, verbose=1, learning_rate=1e-3,
            buffer_size=10, learning_starts=1000, exploration_fraction=0.1)

# Train the model
model.learn(total_timesteps=50000)

# Save the trained model
model.save("dqn_water_supply")

# Evaluate the model over 10 episodes
mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=10)
print(f"Mean reward: {mean_reward:.2f} +/- {std_reward:.2f}")

# Run a few test episodes to observe behavior
test_env = create_env()
obs, info = test_env.reset()
for _ in range(20):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, done, _, info = test_env.step(action)
    test_env.render()
    if done:
        obs, info = test_env.reset()
# Out:
# Using cpu device
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.71e+04 |
# |    exploration_rate | 0.981     |
# | time/               |           |
# |    episodes         | 4         |
# |    fps              | 7143      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 100       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.79e+04 |
# |    exploration_rate | 0.962     |
# | time/               |           |
# |    episodes         | 8         |
# |    fps              | 7325      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 200       |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -1.9e+04 |
# |    exploration_rate | 0.943    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 7078     |
# |    time_elapsed     | 0        |
# |    total_timesteps  | 300      |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.88e+04 |
# |    exploration_rate | 0.924     |
# | time/               |           |
# |    episodes         | 16        |
# |    fps              | 6904      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 400       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.89e+04 |
# |    exploration_rate | 0.905     |
# | time/               |           |
# |    episodes         | 20        |
# |    fps              | 6673      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 500       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.89e+04 |
# |    exploration_rate | 0.886     |
# | time/               |           |
# |    episodes         | 24        |
# |    fps              | 6599      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 600       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.93e+04 |
# |    exploration_rate | 0.867     |
# | time/               |           |
# |    episodes         | 28        |
# |    fps              | 6556      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 700       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.94e+04 |
# |    exploration_rate | 0.848     |
# | time/               |           |
# |    episodes         | 32        |
# |    fps              | 6654      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 800       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.94e+04 |
# |    exploration_rate | 0.829     |
# | time/               |           |
# |    episodes         | 36        |
# |    fps              | 6608      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 900       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.93e+04 |
# |    exploration_rate | 0.81      |
# | time/               |           |
# |    episodes         | 40        |
# |    fps              | 6614      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 1000      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.92e+04 |
# |    exploration_rate | 0.791     |
# | time/               |           |
# |    episodes         | 44        |
# |    fps              | 2785      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 1100      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 889       |
# |    n_updates        | 24        |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.87e+04 |
# |    exploration_rate | 0.772     |
# | time/               |           |
# |    episodes         | 48        |
# |    fps              | 2239      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 1200      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 334       |
# |    n_updates        | 49        |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.81e+04 |
# |    exploration_rate | 0.753     |
# | time/               |           |
# |    episodes         | 52        |
# |    fps              | 1944      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 1300      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 325       |
# |    n_updates        | 74        |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.79e+04 |
# |    exploration_rate | 0.734     |
# | time/               |           |
# |    episodes         | 56        |
# |    fps              | 1751      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 1400      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 1.02e+03  |
# |    n_updates        | 99        |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.77e+04 |
# |    exploration_rate | 0.715     |
# | time/               |           |
# |    episodes         | 60        |
# |    fps              | 1600      |
# |    time_elapsed     | 0         |
# |    total_timesteps  | 1500      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 517       |
# |    n_updates        | 124       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.74e+04 |
# |    exploration_rate | 0.696     |
# | time/               |           |
# |    episodes         | 64        |
# |    fps              | 1491      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 1600      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 481       |
# |    n_updates        | 149       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.72e+04 |
# |    exploration_rate | 0.677     |
# | time/               |           |
# |    episodes         | 68        |
# |    fps              | 1334      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 1700      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 671       |
# |    n_updates        | 174       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.71e+04 |
# |    exploration_rate | 0.658     |
# | time/               |           |
# |    episodes         | 72        |
# |    fps              | 1280      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 1800      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 299       |
# |    n_updates        | 199       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.68e+04 |
# |    exploration_rate | 0.639     |
# | time/               |           |
# |    episodes         | 76        |
# |    fps              | 1231      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 1900      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 449       |
# |    n_updates        | 224       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.66e+04 |
# |    exploration_rate | 0.62      |
# | time/               |           |
# |    episodes         | 80        |
# |    fps              | 1197      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 2000      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 174       |
# |    n_updates        | 249       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.64e+04 |
# |    exploration_rate | 0.601     |
# | time/               |           |
# |    episodes         | 84        |
# |    fps              | 1165      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 2100      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 229       |
# |    n_updates        | 274       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.61e+04 |
# |    exploration_rate | 0.582     |
# | time/               |           |
# |    episodes         | 88        |
# |    fps              | 1140      |
# |    time_elapsed     | 1         |
# |    total_timesteps  | 2200      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 553       |
# |    n_updates        | 299       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.59e+04 |
# |    exploration_rate | 0.563     |
# | time/               |           |
# |    episodes         | 92        |
# |    fps              | 1118      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 2300      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 543       |
# |    n_updates        | 324       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.58e+04 |
# |    exploration_rate | 0.544     |
# | time/               |           |
# |    episodes         | 96        |
# |    fps              | 1096      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 2400      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 417       |
# |    n_updates        | 349       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.56e+04 |
# |    exploration_rate | 0.525     |
# | time/               |           |
# |    episodes         | 100       |
# |    fps              | 1077      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 2500      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 334       |
# |    n_updates        | 374       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.53e+04 |
# |    exploration_rate | 0.506     |
# | time/               |           |
# |    episodes         | 104       |
# |    fps              | 1060      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 2600      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 253       |
# |    n_updates        | 399       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.49e+04 |
# |    exploration_rate | 0.487     |
# | time/               |           |
# |    episodes         | 108       |
# |    fps              | 1045      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 2700      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 209       |
# |    n_updates        | 424       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.43e+04 |
# |    exploration_rate | 0.468     |
# | time/               |           |
# |    episodes         | 112       |
# |    fps              | 1026      |
# |    time_elapsed     | 2         |
# |    total_timesteps  | 2800      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 98.1      |
# |    n_updates        | 449       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.38e+04 |
# |    exploration_rate | 0.449     |
# | time/               |           |
# |    episodes         | 116       |
# |    fps              | 959       |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 2900      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 227       |
# |    n_updates        | 474       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.34e+04 |
# |    exploration_rate | 0.43      |
# | time/               |           |
# |    episodes         | 120       |
# |    fps              | 938       |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 3000      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 210       |
# |    n_updates        | 499       |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -1.3e+04 |
# |    exploration_rate | 0.411    |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 919      |
# |    time_elapsed     | 3        |
# |    total_timesteps  | 3100     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 179      |
# |    n_updates        | 524      |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.24e+04 |
# |    exploration_rate | 0.392     |
# | time/               |           |
# |    episodes         | 128       |
# |    fps              | 910       |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 3200      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 138       |
# |    n_updates        | 549       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.19e+04 |
# |    exploration_rate | 0.373     |
# | time/               |           |
# |    episodes         | 132       |
# |    fps              | 902       |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 3300      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 55.4      |
# |    n_updates        | 574       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.14e+04 |
# |    exploration_rate | 0.354     |
# | time/               |           |
# |    episodes         | 136       |
# |    fps              | 890       |
# |    time_elapsed     | 3         |
# |    total_timesteps  | 3400      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 89.3      |
# |    n_updates        | 599       |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -1.1e+04 |
# |    exploration_rate | 0.335    |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 871      |
# |    time_elapsed     | 4        |
# |    total_timesteps  | 3500     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 171      |
# |    n_updates        | 624      |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.04e+04 |
# |    exploration_rate | 0.316     |
# | time/               |           |
# |    episodes         | 144       |
# |    fps              | 862       |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 3600      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 19.9      |
# |    n_updates        | 649       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.01e+04 |
# |    exploration_rate | 0.297     |
# | time/               |           |
# |    episodes         | 148       |
# |    fps              | 855       |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 3700      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 285       |
# |    n_updates        | 674       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -9.88e+03 |
# |    exploration_rate | 0.278     |
# | time/               |           |
# |    episodes         | 152       |
# |    fps              | 848       |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 3800      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 181       |
# |    n_updates        | 699       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -9.43e+03 |
# |    exploration_rate | 0.259     |
# | time/               |           |
# |    episodes         | 156       |
# |    fps              | 843       |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 3900      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 38.2      |
# |    n_updates        | 724       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -9.05e+03 |
# |    exploration_rate | 0.24      |
# | time/               |           |
# |    episodes         | 160       |
# |    fps              | 838       |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 4000      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 304       |
# |    n_updates        | 749       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -8.73e+03 |
# |    exploration_rate | 0.221     |
# | time/               |           |
# |    episodes         | 164       |
# |    fps              | 832       |
# |    time_elapsed     | 4         |
# |    total_timesteps  | 4100      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 4.63      |
# |    n_updates        | 774       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -8.31e+03 |
# |    exploration_rate | 0.202     |
# | time/               |           |
# |    episodes         | 168       |
# |    fps              | 827       |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 4200      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 112       |
# |    n_updates        | 799       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -7.81e+03 |
# |    exploration_rate | 0.183     |
# | time/               |           |
# |    episodes         | 172       |
# |    fps              | 822       |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 4300      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.00159   |
# |    n_updates        | 824       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -7.54e+03 |
# |    exploration_rate | 0.164     |
# | time/               |           |
# |    episodes         | 176       |
# |    fps              | 818       |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 4400      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 165       |
# |    n_updates        | 849       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -7.18e+03 |
# |    exploration_rate | 0.145     |
# | time/               |           |
# |    episodes         | 180       |
# |    fps              | 815       |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 4500      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 14.7      |
# |    n_updates        | 874       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -6.72e+03 |
# |    exploration_rate | 0.126     |
# | time/               |           |
# |    episodes         | 184       |
# |    fps              | 811       |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 4600      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.119     |
# |    n_updates        | 899       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -6.39e+03 |
# |    exploration_rate | 0.107     |
# | time/               |           |
# |    episodes         | 188       |
# |    fps              | 808       |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 4700      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 267       |
# |    n_updates        | 924       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -6.06e+03 |
# |    exploration_rate | 0.088     |
# | time/               |           |
# |    episodes         | 192       |
# |    fps              | 804       |
# |    time_elapsed     | 5         |
# |    total_timesteps  | 4800      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 10.1      |
# |    n_updates        | 949       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -5.57e+03 |
# |    exploration_rate | 0.069     |
# | time/               |           |
# |    episodes         | 196       |
# |    fps              | 799       |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 4900      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 28.1      |
# |    n_updates        | 974       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -5.12e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 200       |
# |    fps              | 795       |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 5000      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 4.11      |
# |    n_updates        | 999       |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -4.81e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 204       |
# |    fps              | 791       |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 5100      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 22.2      |
# |    n_updates        | 1024      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -4.54e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 208       |
# |    fps              | 788       |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 5200      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 1.47      |
# |    n_updates        | 1049      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -4.32e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 212       |
# |    fps              | 786       |
# |    time_elapsed     | 6         |
# |    total_timesteps  | 5300      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 26.4      |
# |    n_updates        | 1074      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -4.1e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 783      |
# |    time_elapsed     | 6        |
# |    total_timesteps  | 5400     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 64.2     |
# |    n_updates        | 1099     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -3.81e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 220       |
# |    fps              | 778       |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 5500      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.00255   |
# |    n_updates        | 1124      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -3.55e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 224       |
# |    fps              | 776       |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 5600      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 3.84e-05  |
# |    n_updates        | 1149      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -3.33e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 228       |
# |    fps              | 773       |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 5700      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.0811    |
# |    n_updates        | 1174      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -3.04e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 232       |
# |    fps              | 771       |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 5800      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.00568   |
# |    n_updates        | 1199      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -2.72e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 236       |
# |    fps              | 769       |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 5900      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.0109    |
# |    n_updates        | 1224      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -2.47e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 240       |
# |    fps              | 768       |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 6000      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 122       |
# |    n_updates        | 1249      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -2.37e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 244       |
# |    fps              | 767       |
# |    time_elapsed     | 7         |
# |    total_timesteps  | 6100      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.000113  |
# |    n_updates        | 1274      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -2.17e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 248       |
# |    fps              | 765       |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 6200      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 1.41      |
# |    n_updates        | 1299      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -2e+03   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 762      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 6300     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 16.7     |
# |    n_updates        | 1324     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.86e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 256       |
# |    fps              | 760       |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 6400      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.00871   |
# |    n_updates        | 1349      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.63e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 260       |
# |    fps              | 758       |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 6500      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.0425    |
# |    n_updates        | 1374      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -1.5e+03 |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 757      |
# |    time_elapsed     | 8        |
# |    total_timesteps  | 6600     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0133   |
# |    n_updates        | 1399     |
# ----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.39e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 268       |
# |    fps              | 755       |
# |    time_elapsed     | 8         |
# |    total_timesteps  | 6700      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.00306   |
# |    n_updates        | 1424      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.32e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 272       |
# |    fps              | 754       |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 6800      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 35        |
# |    n_updates        | 1449      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.13e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 276       |
# |    fps              | 753       |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 6900      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 2.6       |
# |    n_updates        | 1474      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.06e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 280       |
# |    fps              | 751       |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 7000      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 92        |
# |    n_updates        | 1499      |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.03e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 284       |
# |    fps              | 750       |
# |    time_elapsed     | 9         |
# |    total_timesteps  | 7100      |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.0115    |
# |    n_updates        | 1524      |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -970     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 749      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 7200     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 14.3     |
# |    n_updates        | 1549     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -865     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 747      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 7300     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.33     |
# |    n_updates        | 1574     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -859     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 746      |
# |    time_elapsed     | 9        |
# |    total_timesteps  | 7400     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.87     |
# |    n_updates        | 1599     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -883     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 743      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 7500     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0628   |
# |    n_updates        | 1624     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -862     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 742      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 7600     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00449  |
# |    n_updates        | 1649     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -839     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 739      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 7700     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 9.69     |
# |    n_updates        | 1674     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -835     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 737      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 7800     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00296  |
# |    n_updates        | 1699     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -825     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 736      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 7900     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00215  |
# |    n_updates        | 1724     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -806     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 734      |
# |    time_elapsed     | 10       |
# |    total_timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0196   |
# |    n_updates        | 1749     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -789     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 732      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 8100     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00451  |
# |    n_updates        | 1774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -800     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 728      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 8200     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 96.8     |
# |    n_updates        | 1799     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -787     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 720      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 8300     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00169  |
# |    n_updates        | 1824     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -826     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 715      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 8400     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.083    |
# |    n_updates        | 1849     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -824     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 711      |
# |    time_elapsed     | 11       |
# |    total_timesteps  | 8500     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 5.05     |
# |    n_updates        | 1874     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -814     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 707      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 8600     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.024    |
# |    n_updates        | 1899     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -812     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 703      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 8700     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.09     |
# |    n_updates        | 1924     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -791     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 699      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 8800     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0184   |
# |    n_updates        | 1949     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -766     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 694      |
# |    time_elapsed     | 12       |
# |    total_timesteps  | 8900     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0354   |
# |    n_updates        | 1974     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -801     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 690      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 9000     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0103   |
# |    n_updates        | 1999     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -837     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 687      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 9100     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000615 |
# |    n_updates        | 2024     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -826     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 684      |
# |    time_elapsed     | 13       |
# |    total_timesteps  | 9200     |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.00172  |
# |    n_updates        | 2049     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -847     |
# ...
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 4.03      |
# |    n_updates        | 11649     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.17e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1908      |
# |    fps              | 465       |
# |    time_elapsed     | 102       |
# |    total_timesteps  | 47700     |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.0279    |
# |    n_updates        | 11674     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.19e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1912      |
# |    fps              | 465       |
# |    time_elapsed     | 102       |
# |    total_timesteps  | 47800     |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 3.17      |
# |    n_updates        | 11699     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.19e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1916      |
# |    fps              | 465       |
# |    time_elapsed     | 102       |
# |    total_timesteps  | 47900     |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.00224   |
# |    n_updates        | 11724     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.18e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1920      |
# |    fps              | 465       |
# |    time_elapsed     | 103       |
# |    total_timesteps  | 48000     |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.0317    |
# |    n_updates        | 11749     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.14e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1924      |
# |    fps              | 465       |
# |    time_elapsed     | 103       |
# |    total_timesteps  | 48100     |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.0239    |
# |    n_updates        | 11774     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.13e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1928      |
# |    fps              | 465       |
# |    time_elapsed     | 103       |
# |    total_timesteps  | 48200     |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 2.69      |
# |    n_updates        | 11799     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.13e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1932      |
# |    fps              | 465       |
# |    time_elapsed     | 103       |
# |    total_timesteps  | 48300     |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.018     |
# |    n_updates        | 11824     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.08e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1936      |
# |    fps              | 465       |
# |    time_elapsed     | 104       |
# |    total_timesteps  | 48400     |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.0179    |
# |    n_updates        | 11849     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.03e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1940      |
# |    fps              | 465       |
# |    time_elapsed     | 104       |
# |    total_timesteps  | 48500     |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.0232    |
# |    n_updates        | 11874     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.02e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1944      |
# |    fps              | 465       |
# |    time_elapsed     | 104       |
# |    total_timesteps  | 48600     |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.0836    |
# |    n_updates        | 11899     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.02e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1948      |
# |    fps              | 464       |
# |    time_elapsed     | 104       |
# |    total_timesteps  | 48700     |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.0339    |
# |    n_updates        | 11924     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.01e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1952      |
# |    fps              | 464       |
# |    time_elapsed     | 105       |
# |    total_timesteps  | 48800     |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.00658   |
# |    n_updates        | 11949     |
# -----------------------------------
# -----------------------------------
# | rollout/            |           |
# |    ep_len_mean      | 25        |
# |    ep_rew_mean      | -1.01e+03 |
# |    exploration_rate | 0.05      |
# | time/               |           |
# |    episodes         | 1956      |
# |    fps              | 464       |
# |    time_elapsed     | 105       |
# |    total_timesteps  | 48900     |
# | train/              |           |
# |    learning_rate    | 0.001     |
# |    loss             | 0.257     |
# |    n_updates        | 11974     |
# -----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -971     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1960     |
# |    fps              | 464      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 49000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.627    |
# |    n_updates        | 11999    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -978     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1964     |
# |    fps              | 464      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 49100    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0721   |
# |    n_updates        | 12024    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -1e+03   |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1968     |
# |    fps              | 464      |
# |    time_elapsed     | 105      |
# |    total_timesteps  | 49200    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 7.13     |
# |    n_updates        | 12049    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -990     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1972     |
# |    fps              | 464      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 49300    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 4.96     |
# |    n_updates        | 12074    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -936     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1976     |
# |    fps              | 464      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 49400    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.503    |
# |    n_updates        | 12099    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -933     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1980     |
# |    fps              | 464      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 49500    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000227 |
# |    n_updates        | 12124    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -913     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1984     |
# |    fps              | 464      |
# |    time_elapsed     | 106      |
# |    total_timesteps  | 49600    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0136   |
# |    n_updates        | 12149    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -944     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1988     |
# |    fps              | 464      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 49700    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.000381 |
# |    n_updates        | 12174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -934     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1992     |
# |    fps              | 464      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 49800    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.063    |
# |    n_updates        | 12199    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -926     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 1996     |
# |    fps              | 463      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 49900    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.0257   |
# |    n_updates        | 12224    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 25       |
# |    ep_rew_mean      | -888     |
# |    exploration_rate | 0.05     |
# | time/               |          |
# |    episodes         | 2000     |
# |    fps              | 463      |
# |    time_elapsed     | 107      |
# |    total_timesteps  | 50000    |
# | train/              |          |
# |    learning_rate    | 0.001    |
# |    loss             | 0.76     |
# |    n_updates        | 12249    |
# ----------------------------------
# Mean reward: -0.31 +/- 0.00
# {'water_level': 300.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 75.0, 'current_time_bucket': 1, 'current_cycle': 0, 'total_reward': -0.0125}
# {'water_level': 225.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 2, 'current_cycle': 0, 'total_reward': -0.025}
# {'water_level': 225.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 3, 'current_cycle': 0, 'total_reward': -0.037500000000000006}
# {'water_level': 225.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 4, 'current_cycle': 0, 'total_reward': -0.05}
# {'water_level': 225.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 0, 'current_cycle': 1, 'total_reward': -0.0625}
# {'water_level': 225.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 1, 'current_cycle': 1, 'total_reward': -0.075}
# {'water_level': 225.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 2, 'current_cycle': 1, 'total_reward': -0.0875}
# {'water_level': 225.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 3, 'current_cycle': 1, 'total_reward': -0.09999999999999999}
# {'water_level': 225.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 75.0, 'current_time_bucket': 4, 'current_cycle': 1, 'total_reward': -0.11249999999999999}
# {'water_level': 150.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 0, 'current_cycle': 2, 'total_reward': -0.12499999999999999}
# {'water_level': 150.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 1, 'current_cycle': 2, 'total_reward': -0.13749999999999998}
# {'water_level': 150.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 2, 'current_cycle': 2, 'total_reward': -0.15}
# {'water_level': 150.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 3, 'current_cycle': 2, 'total_reward': -0.1625}
# {'water_level': 150.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 4, 'current_cycle': 2, 'total_reward': -0.17500000000000002}
# {'water_level': 150.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 0, 'current_cycle': 3, 'total_reward': -0.18750000000000003}
# {'water_level': 150.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 1, 'current_cycle': 3, 'total_reward': -0.20000000000000004}
# {'water_level': 150.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 2, 'current_cycle': 3, 'total_reward': -0.21250000000000005}
# {'water_level': 150.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 3, 'current_cycle': 3, 'total_reward': -0.22500000000000006}
# {'water_level': 150.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 4, 'current_cycle': 3, 'total_reward': -0.23750000000000007}
# {'water_level': 150.0, 'price_A': 1.0, 'price_B': 1.5, 'demand': 0.0, 'current_time_bucket': 0, 'current_cycle': 4, 'total_reward': -0.25000000000000006}
